# %%
import pickle 
with open('myfirstmodel.pkl','rb')as file:
    mymodel=pickle.load(file)

# %%
mymodel
# Out:
# LinearRegression()

# %%
val=[[50,30,10]]

# %%
#!pip install import-ipynb

# %%
import import_ipynb
from project1 import *
# Out:
# importing Jupyter notebook from project1.ipynb
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB
# 0.9184783854478343
# 0.9116849175684871
# 0.9310544768869486
# 0.9253090166275277

# %%
val=[[0,100,0]]
ScaledVal=scaling.transform(val)
ScaledVal
# Out:
# array([[-0.00236726,  2.01612903, -0.003367  ]])

# %%
mymodel.predict(ScaledVal)
# Out:
# array([21.51909334])

# %% [markdown]
# ## Conclusion

# %% [markdown]
# From the above predictive model, My conclusion that investing more in radio is a sound decision is backed by the data-driven insights obtained from my predictive model. This finding can guide strategic decisions in marketing investments to achieve better outcomes.
